# %%
# Exercise 1: In the code below, which will never print regardless of the value for x? Edit the code to correct the error.

x = int(input('Enter a number: '))

if x > 50:
 print('Above 50')
elif x > 20:
  print('Above 20')
elif x > 10:
  print('Above 10')
elif x > 0:
  print('Above 0')
else:
  print('Something else')
# Out:
# Enter a number: 25
# Above 20

# %%
# Exercise 2: Write your salary computation to give an employee 1.5 times the hourly rate for hours worked above 40 hours.

hours = float(input('Enter hours: '))
rate = float(input('Enter rate: '))

if hours > 40:
  regular = 40 * rate
  overtime = (hours - 40) * (rate * 1.5)
  pay = regular + overtime
else:
  pay = hours * rate

print('Pay: ', pay)
# Out:
# Enter hours: 45
# Enter rate: 10
# Pay:  475.0

# %%
CHALLENGE

# %%
# CHALLENGE:

score = float(input('Enter score (0-100): '))

if score < 0 or score > 100:
   print('Invalid score, please input a number between 0-100.')
else:
   if score >= 98:
    grade = 1.0
   elif score >= 94:
    grade = 1.25
   elif score >= 90:
    grade = 1.5
   elif score >= 86:
    grade = 1.75
   elif score >= 82:
    grade = 2.0
   elif score >= 78:
    grade = 2.25
   elif score >= 75:
    grade = 2.5
   else:
    grade = 5.0

print('Grade: ', grade)
# Out:
# Enter score (0-100): 89
# Grade:  1.75
