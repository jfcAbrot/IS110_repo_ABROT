# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/IS110_BusinessP_Abrot/PythonEnvi1_Abrot
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BusinessP_Abrot/PythonEnvi1_Abrot

# %%
# !pwd
#for the working directory
# Out:
# /content/drive/MyDrive/ColabNotebooks/IS110_BusinessP_Abrot/PythonEnvi1_Abrot

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 76.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 28.7 MB/s eta 0:00:00
# ...

# %%
# !virtualenv NextLine
# Out:
# created virtual environment CPython3.12.12.final.0-64-x86_64 in 11080ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/ColabNotebooks/IS110_BusinessP_Abrot/PythonEnvi1_Abrot/NextLine, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.0.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source NextLine/bin/activate

# %%
# %%writefile requirements.txt
# pandas
# numpy
# Out:
# Overwriting requirements.txt

# %%
#install the packages in the requirements.txt
# !NextLine//bin/pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 35.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 33.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]
# ...

# %%
#requirements.txt has been created or updated
# !NextLine//bin/pip freeze > requirements.txt

# %%
# !NextLine/bin/pip list
# Out:
# Package         Version
# --------------- -----------
# numpy           2.4.2
# pandas          3.0.1
# pip             26.0.1
# python-dateutil 2.9.0.post0
# six             1.17.0

# %%
# !cat requirements.txt
# Out:
# numpy==2.4.2
# pandas==3.0.1
# python-dateutil==2.9.0.post0
# six==1.17.0

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')
print('Done')
# Out:
# Done

# %%
ls
# Out:
# Chapter2.ipynb  IS110_Repo_ABROT/  NextLine/  requirements.txt  Untitled0.ipynb

# %%
df = pd.read_csv('dataset/reviews.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_301/3685146589.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('dataset/reviews.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
#Write a program to prompt the user for hours and rate per hour to compute gross pay.

hours = input('Enter hours: ')
rate = input("Enter rate: ")
pay = int(hours) * float(rate)
print('Total income: ',pay)
# Out:
# Enter hours: 3
# Enter rate: 4
# Total income:  12.0

# %%
#width//2 width/2.0 height/3  1 + 2 * 5 */
width = 17
height = 12.0

print('width // 2 =',width//2)
print('width / 2 =',width/2)
print('height / 3 =',height/3)
print('1 + 2 * 5 =',1+2*5)
# Out:
# width // 2 = 8
# width / 2 = 8.5
# height / 3 = 4.0
# 1 + 2 * 5 = 11

# %%
#Write a program that uses input to prompt a user for a number and then outputs the square of the number
number = int(input('Enter a number: '))
square = int(number) * int(number)
print('the square of',number, 'is',square)
# Out:
# Enter a number: 2
# the square of 2 is 4

# %%
cel = float(input("Enter temperature in Celsius: "))
fc = (cel * 9/5) + 32
print(fc)
# Out:
# Enter temperature in Celsius: 5
# 41.0
